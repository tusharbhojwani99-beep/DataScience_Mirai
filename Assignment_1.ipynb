# %% [markdown]
# <a href="https://colab.research.google.com/github/tusharbhojwani99-beep/DataScience_Mirai/blob/main/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

n = int(input("Number of items : "))

prices = []

for i in range(n):
    prices.append(int(input(f"Item {i+1} => ")))

prices = np.array(prices)

print("Prices =", prices)

print("Total Bill    =" , np.sum(prices))
print("Average Price =" , np.mean(prices))
print("Std Dev       =" , np.std(prices))
print("Unique Prices =" , np.unique(prices))
print("Sorted Prices =" , np.sort(prices))
print("Minimum Price =" , np.min(prices))
print("Maximum Price =" , np.max(prices))


print("Items > 100   =" , prices[np.where(prices > 100)])
# Out:
# Number of items : 5
# Item 1 =>34
# Item 2 =>34
# Item 3 =>34
# Item 4 =>56
# Item 5 =>47
# Prices = [34 34 34 56 47]
# Total Bill    = 205
# Average Price = 41.0
# Std Dev       = 9.033271832508971
# Unique Prices = [34 47 56]
# Sorted Prices = [34 34 34 47 56]
# Minimum Price = 34
# Maximum Price = 56
# Items > 100   = []
