# %% [markdown]
# <a href="https://colab.research.google.com/github/Sauvi72/Data_sci_Python/blob/main/lec_03_string_dict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def add(a,b):
  # body of the function
  return a+b
add(4,5)
# Out:
# 9

# %%
# lambda function
x = lambda a : 2*a
print(x(2))
# Out:
# 4

# %%
x = lambda a : 2*a
y = lambda b : 3*b
print(x(2)+y(3))
# Out:
# 13

# %%
x = lambda a , b : b * a
print(x(2,3))
# Out:
# 9

# %%
st = ""
print(len(st))

st = "saurav"
finl = st.upper()                        #  .upper() -------------> convert lowercases to uppercase
print(len(st))

print(finl)
# Out:
# 0
# 6
# SAURAV

# %%
st = "SauraV VoUrav ZouRav"
final1 = st.lower()
final2 = st.upper()
final3 = st.title()
final4 = st.capitalize()

print(final1)
print(final2)
print(final3)
print(final4)
# Out:
# saurav vourav zourav
# SAURAV VOURAV ZOURAV
# Saurav Vourav Zourav
# Saurav vourav zourav

# %%
first_name = 'saurav'
last_name = 'kumar'

#strip

first_name = first_name.strip()
last_name = last_name.strip()

print(first_name+' ' +last_name)
# Out:
# saurav kumar

# %%
a=" today "
b = "  weather"
c = "is GooD"
a=a.strip()
b=b.strip()
c=c.strip()
st = a+" "+b+" "+c
st = st.capitalize()
print(st)
st=st.replace("good","bad")
print(st)
# Out:
# Today weather is good
# Today weather is bad

# %%
st = "Today weather is good"

a = st.find('r')
print(a)
# Out:
# 12

# %%
st = "Today weather is good"

a = st.find('z')             #return -1 if the specific element not found

print(a)
# Out:
# -1

# %%
st = "Today weather is good"
a = st.find('w')
print(a)
# Out:
# 6

# %%
st = "Today weather is good"

a = st.startswith('today')
b = st.endswith('good')

print(a)
print(b)
# Out:
# False
# True

# %%
st = "Today weather is good"

a = st.count('o')
print(a)
# Out:
# 3

# %%
st = "Today weather is good"

sortedelement = sorted(st)
print(sortedelement)
# Out:
# [' ', ' ', ' ', 'T', 'a', 'a', 'd', 'd', 'e', 'e', 'g', 'h', 'i', 'o', 'o', 'o', 'r', 's', 't', 'w', 'y']

# %%
S = "hello world"

print(S[6:])
print(S[6:11])
print(S[:11])
# Out:
# world
# world
# hello world

# %%
# set

st = {2 , 2 , 23 , 2 , 1}

print(st)
print(type(s))
# Out:
# {1, 2, 23}
# <class 'str'>

# %%
# typecasting list to set
s = set(["a", "b", "c"])
print(s)

# Adding element to the set
s.add("d")
print(s)
# Out:
# {'b', 'c', 'a'}
# {'b', 'd', 'c', 'a'}

# %%
# TOPIC CHANGES
# |
# |
# |
# |
# |
# ↓

# %%
#Dictionary

dct = {
    "name":[ "rakesh","mohan" , "hifive"] ,
    "age" : 200 ,
    "occupation" : 10 ,
    "roll no. "  :26 ,

}

print(dct)
print(dct["name"])
print(dct["name"][1])
print(dct["age"])
print(dct["occupation"])
print(dct["roll no. "])


dct['id'] = 12
print(dct)


del dct["name"]       # ----------------------------> {deletes the specific directed element}
print(dct)
# Out:
# {'name': ['rakesh', 'mohan', 'hifive'], 'age': 200, 'occupation': 10, 'roll no. ': 26}
# ['rakesh', 'mohan', 'hifive']
# mohan
# 200
# 10
# 26
# {'name': ['rakesh', 'mohan', 'hifive'], 'age': 200, 'occupation': 10, 'roll no. ': 26, 'id': 12}
# {'age': 200, 'occupation': 10, 'roll no. ': 26, 'id': 12}
